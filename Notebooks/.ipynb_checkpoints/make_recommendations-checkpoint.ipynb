# %% [markdown]
# The goal of this notebook is to make functions to make recommendations for the data we scraped and then choose the function that makes the best recommendations

# %%
import pandas as pd

# %%
sim = pd.read_csv('../data/recommendation_matrix.csv') 
sim_1 = pd.read_csv('../data/recommendation_matrix_wo_tfidf.csv')
sim_2 = pd.read_csv('../data/recommendation_matrix_w_lem.csv')
sim_3 = pd.read_csv('../data/recommendation_matrix_w_lem_wo_tfidf.csv')
df = pd.read_csv('../data/recomm_df.csv')
sim_cat = pd.read_csv('../data/recommendation_df_cat.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-c10fcebde95b> in <module>()
# ----> 1 sim = pd.read_csv('../data/recommendation_matrix.csv')
#       2 sim_1 = pd.read_csv('../data/recommendation_matrix_wo_tfidf.csv')
#       3 sim_2 = pd.read_csv('../data/recommendation_matrix_w_lem.csv')
#       4 sim_3 = pd.read_csv('../data/recommendation_matrix_w_lem_wo_tfidf.csv')
#       5 df = pd.read_csv('../data/recomm_df.csv')
#
# NameError: name 'pd' is not defined

# %% [markdown]
# Thus we have the following dataframes loaded:
#
# **sim** : similarity matrix with stemming and tfidf
#
# **sim_1** : similarity matrix made without using tfidf but with stemming
#
# **sim_2** : similarity matrix made with lemmatizing and tfidf
#
# **sim_3** : similarity matrix made with lemmatization and without tfidf
#
# **df** : dataframe with all the internships
#
# **sim_cat** : similarity matrix made using category column and with stemming but without tfidf

# %%
# setting id column as index
sim.set_index('id', inplace = True)
sim_1.set_index('id', inplace = True)
sim_2.set_index('id', inplace = True)
sim_3.set_index('id', inplace = True)
sim_cat.set_index('id', inplace = True)

# %% [markdown]
# Making the recommendation function:

# %%
def make_recs(sim, df, i, n):
    '''
    returns a dataframe of top n recommendations, based on the similarity matrix provided and dataframe 
    provided, for a user who viewed the internship with the ith ID.
    
    INPUT:
    sim - similarity matrix(dataframe)
    df - original dataframe with all the data
    i - id of the internship that was viewed by the user
    n - top n recommendations to be made to the user 
    
    OUTPUT:
    recs_df - dataframe consisting of the recommended internships
    
    '''
    ith_series = sim.loc[:,str(i)]
    ith_series = ith_series.sort_values(ascending = False)
    recs = ith_series.head(n+1).index.tolist()
    
    # what might happen is that multiple elements attain maximum similarity value. Then it is possible that 
    # we don't get i in our recs. so for that the below is done. 
    if i in recs: 
        recs.remove(i)
    else:
        recs = recs[:-1]
        
    # below ensures that the order of the recommendations is as in recs cause otherwise the use of .isin
    # reorders recs in the way they appear in df, i.e, in ascending order
    recs_df = df[df.id.isin(recs)].set_index('id').T[recs].T.reset_index()
    
    return recs_df

# %% [markdown]
# Running an example below for all the similarity matrices :

# %%
# original internship viewed by the user
df[df.id == 110]
# Out:
#       id              job_title            company_name job_loc  \
# 106  110  hr recruitment intern  infytalent hr services    pune
#
#                                                details  \
# 106                 we are looking for hr traineere...
#
#                       category compensation       start         end  \
# 106  human resources recruiter         paid  2019-02-17  2019-12-30
#
#                               skills  \
# 106                    agreeableness
#
#                                                   href
# 106  http://letsintern.com/internship/Human-Resourc...

# %% [markdown]
# ### Recommended internships using different dataframes :

# %% [markdown]
# ### for sim :

# %%
make_recs(sim, df, 110, 3)
# Out:
#     id                                          job_title  \
# 0  499                              hr recruitment intern
# 1  303                           hr recruitment executive
# 2  203  hr / human resource / recruitment / administra...
#
#              company_name            job_loc  \
# 0  infytalent hr services  anywhere in india
# 1        brilliant seeker              thane
# 2                  manpho  anywhere in india
#
#                                              details  \
# 0                 we are looking for hr traineere...
# 1                 end to end recruitmentindividua...
# 2                 we are seeking hr (human resour...
#
#                     category compensation       start         end  \
# 0  human resources recruiter         paid  2019-02-17  2019-12-30
# 1  human resources assistant         paid  2018-11-05  2019-10-30
# 2  human resources recruiter       unpaid  2019-03-05  2019-03-29
#
#                                               skills  \
# 0                                no skills preferred
# 1                    english comprehension,comput...
# 2                                no skills preferred
#
#                                                 href
# 0  http://letsintern.com/internship/Human-Resourc...
# 1  http://letsintern.com/internship/Human-Resourc...
# 2  http://letsintern.com/internship/Human-Resourc...

# %% [markdown]
# ### for sim_1 :

# %%
make_recs(sim_1, df, 110, 3)
# Out:
#     id                         job_title            company_name  \
# 0  499             hr recruitment intern  infytalent hr services
# 1  225  laravel backend developer intern                  intact
# 2  303          hr recruitment executive        brilliant seeker
#
#              job_loc                                            details  \
# 0  anywhere in india                 we are looking for hr traineere...
# 1  anywhere in india                 we are looking for back-end dev...
# 2              thane                 end to end recruitmentindividua...
#
#                     category compensation       start         end  \
# 0  human resources recruiter         paid  2019-02-17  2019-12-30
# 1              web developer         paid  2019-01-06  2019-06-30
# 2  human resources assistant         paid  2018-11-05  2019-10-30
#
#                                               skills  \
# 0                                no skills preferred
# 1                         javascript,php,jquery,ajax
# 2                    english comprehension,comput...
#
#                                                 href
# 0  http://letsintern.com/internship/Human-Resourc...
# 1  http://letsintern.com/internship/Web-Developer...
# 2  http://letsintern.com/internship/Human-Resourc...

# %% [markdown]
# ### for sim_2 :

# %%
make_recs(sim_2, df, 110, 3)
# Out:
#     id                                          job_title  \
# 0  499                              hr recruitment intern
# 1  303                           hr recruitment executive
# 2  203  hr / human resource / recruitment / administra...
#
#              company_name            job_loc  \
# 0  infytalent hr services  anywhere in india
# 1        brilliant seeker              thane
# 2                  manpho  anywhere in india
#
#                                              details  \
# 0                 we are looking for hr traineere...
# 1                 end to end recruitmentindividua...
# 2                 we are seeking hr (human resour...
#
#                     category compensation       start         end  \
# 0  human resources recruiter         paid  2019-02-17  2019-12-30
# 1  human resources assistant         paid  2018-11-05  2019-10-30
# 2  human resources recruiter       unpaid  2019-03-05  2019-03-29
#
#                                               skills  \
# 0                                no skills preferred
# 1                    english comprehension,comput...
# 2                                no skills preferred
#
#                                                 href
# 0  http://letsintern.com/internship/Human-Resourc...
# 1  http://letsintern.com/internship/Human-Resourc...
# 2  http://letsintern.com/internship/Human-Resourc...

# %% [markdown]
# ###  for sim_3 :

# %%
make_recs(sim_3, df, 110,3)
# Out:
#     id                         job_title            company_name  \
# 0  499             hr recruitment intern  infytalent hr services
# 1  225  laravel backend developer intern                  intact
# 2  303          hr recruitment executive        brilliant seeker
#
#              job_loc                                            details  \
# 0  anywhere in india                 we are looking for hr traineere...
# 1  anywhere in india                 we are looking for back-end dev...
# 2              thane                 end to end recruitmentindividua...
#
#                     category compensation       start         end  \
# 0  human resources recruiter         paid  2019-02-17  2019-12-30
# 1              web developer         paid  2019-01-06  2019-06-30
# 2  human resources assistant         paid  2018-11-05  2019-10-30
#
#                                               skills  \
# 0                                no skills preferred
# 1                         javascript,php,jquery,ajax
# 2                    english comprehension,comput...
#
#                                                 href
# 0  http://letsintern.com/internship/Human-Resourc...
# 1  http://letsintern.com/internship/Web-Developer...
# 2  http://letsintern.com/internship/Human-Resourc...

# %% [markdown]
# ### for sim_cat :

# %%
make_recs(sim_cat, df, 110, 3)
# Out:
#     id                                        job_title  \
# 0  331  direct interview  for cargo in kolkata  airport
# 1  279                           us it staffing interns
# 2  499                            hr recruitment intern
#
#              company_name            job_loc  \
# 0                    iips            kolkata
# 1  isl tech solutions inc               pune
# 2  infytalent hr services  anywhere in india
#
#                                              details  \
# 0                 freshers are welcome to face th...
# 1                 candidates with good communicat...
# 2                 we are looking for hr traineere...
#
#                     category compensation       start         end  \
# 0  human resources recruiter         paid  2019-03-04         NaN
# 1  human resources recruiter         paid  2019-03-14         NaN
# 2  human resources recruiter         paid  2019-02-17  2019-12-30
#
#                                   skills  \
# 0                      analytical skills
# 1                           hr practices
# 2                    no skills preferred
#
#                                                 href
# 0  http://letsintern.com/internship/Human-Resourc...
# 1  http://letsintern.com/internship/Human-Resourc...
# 2  http://letsintern.com/internship/Human-Resourc...

# %% [markdown]
# Now after a lot of mixing and matching and trying out for different ids, we came upon the decision to take a weighted sum of sim_cat and sim_1 where sim_cat will be as it is and sim_1 will be multiplied by 0.3. we do this because the weighted sum gives us a really good mix of good and relevant recommendations with seredipitious recommendations. A lot of recommendations by sim_1 are a little offbeat and help us in keeping the recommendations fresh and the users interest intact. The decision of taking the weights as 1 and 0.3 have come from experimentation and by looking at the values of sim_1 and sim_cat(sim_1 has the largest value of 520 whereas sim_cat has 5).
#
# We have done this as recommendation systems are a mix of science and art and this was the art portion where there was no exact way to determine which recommendation system was performing the best.

# %%
def combine_make_recs(df, i, n):
    '''
    takes the weighted sum of 2 similarity matrices: sim_cat and sim_1. Returns recommendations using the 
    summed up matrix.
    
    INPUT:
    df - original dataframe with all the data
    i - id of the internship that was viewed by the user
    n - top n recommendations to be made to the user 
    
    OUTPUT:
    recs_df - dataframe consisting of the recommended internships
    
    '''
    sim_combined = 0.3*sim_1 + sim_cat
    recs_df = make_recs(sim_combined, df, i, n)
    return recs_df

# %%
combine_make_recs(df, 110, 3)
# Out:
#     id                                          job_title  \
# 0  499                              hr recruitment intern
# 1  303                           hr recruitment executive
# 2  255  mba internship program with highrise at ahmedabad
#
#                            company_name            job_loc  \
# 0                infytalent hr services  anywhere in india
# 1                      brilliant seeker              thane
# 2  highrise management services pvt ltd          ahmedabad
#
#                                              details  \
# 0                 we are looking for hr traineere...
# 1                 end to end recruitmentindividua...
# 2                 dear candidate,highrise is one ...
#
#                        category compensation       start         end  \
# 0     human resources recruiter         paid  2019-02-17  2019-12-30
# 1     human resources assistant         paid  2018-11-05  2019-10-30
# 2  human resources professional       unpaid  2019-03-31  2019-07-30
#
#                                               skills  \
# 0                                no skills preferred
# 1                    english comprehension,comput...
# 2                    human resource situation han...
#
#                                                 href
# 0  http://letsintern.com/internship/Human-Resourc...
# 1  http://letsintern.com/internship/Human-Resourc...
# 2  http://letsintern.com/internship/Human-Resourc...
